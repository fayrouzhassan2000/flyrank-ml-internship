# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fayrouzhassan2000/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# Classification.\
# The business goal is to prioritize pages for SEO review, but I frame it as a binary classification problem by predicting whether a page is likely to be declining. The predicted probabilities can then be used to rank pages by review priority and support actions such as refresh, expansion, protection, pruning, or monitoring.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Proxy target: is_declining_label, where a page is labeled as 1 if trend_direction == "down" and 0 otherwise.
# This is a rule-defined proxy because the dataset does not provide a direct label indicating whether a page should be refreshed or reviewed. Instead, declining performance is used as a proxy for review priority. The trend columns are used only to create the target and are excluded from the model features to avoid data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Precision@20. The SEO team is most likely to review only the highest-priority pages, so Precision@20 measures how many of the top 20 recommended pages truly require review. A higher Precision@20 means the ranking is more useful for prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row represents one content page. Each row contains SEO, traffic, engagement, and content-related metrics describing that page over a defined time period.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A simple rule cannot capture the complex relationships between SEO metrics. For example, a page with low CTR may still perform well because it ranks highly, while an older page with strong engagement may not need a refresh. Machine learning can combine multiple signals such as search volume, CTR, average position, engagement, freshness, and traffic to identify patterns and prioritize pages more effectively than fixed if-statements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
